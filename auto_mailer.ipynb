# %%
import smtplib
from email.message import EmailMessage
import mimetypes

import smtplib
from email.message import EmailMessage

from email.utils import make_msgid
import mimetypes

import pandas as pd
import numpy as np

import matplotlib.pyplot

# %%
html_content_long = """
        <div id=":mx" class="ii gt" jslog="20277; u014N:xr6bB; 1:WyIjdGhyZWFkLWY6MTc5ODcwMDg4NTAxODE5ODQ0NSJd; 4:WyIjbXNnLWY6MTc5ODcwMDg4NTAxODE5ODQ0NSJd"><div id=":mw" class="a3s aiL msg8042271865442434460"><div class="adM">
<div dir="ltr"><div class="adM">
</div><p style="text-align:left;text-indent:0px;background-color:white;margin-top:0px;margin-bottom:0px">
<span style="font-family:&quot;Times New Roman&quot;,serif;font-size:11.5pt;color:rgb(131,60,11)"><b><br>ACS Team</b></span></p>
<table style="text-align:left;background-color:white;color:rgb(36,36,36);box-sizing:border-box;border-collapse:collapse;border-spacing:0px">
<tbody>
<tr>
<td style="text-align:left;padding:0.75pt;width:381.75pt;height:107.25pt">
<table style="text-align:left;width:380.25pt;box-sizing:border-box;border-collapse:collapse;border-spacing:0px">
<tbody>
<tr>
<td style="text-align:left;padding:0.75pt;width:3.7pt;height:105.75pt"></td>
<td style="text-align:left;padding:0.75pt;width:161.9pt;height:105.75pt">
<p style="text-align:left;line-height:12.6pt;margin-top:0px;margin-bottom:0px">
<span style="font-family:&quot;Segoe UI&quot;,sans-serif;font-size:10.5pt;color:black"><img alt="A logo of a security company
Description automatically generated" id="m_8042271865442434460x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_Picture_x0020_6" width="216" height="138" style="width:162pt;height:103.5pt;min-width:auto;min-height:auto;margin:0px;vertical-align:top" size="51187" src="ACS_icon.png" data-image-whitelisted="" class="CToWUd a6T" data-bit="iit" tabindex="0">
<div class="a6S" dir="ltr" style="opacity: 0.01; left: 184.688px; top: 131.5px;"><span data-is-tooltip-wrapper="true" class="a5q" jsaction="JIbuQc:.CLIENT"><button class="VYBDae-JX-I VYBDae-JX-I-ql-ay5-ays CgzRE" jscontroller="PIVayb" jsaction="click:h5M12e; clickmod:h5M12e;pointerdown:FEiYhc;pointerup:mF5Elf;pointerenter:EX0mI;pointerleave:vpvbp;pointercancel:xyn4sd;contextmenu:xexox;focus:h06R8; blur:zjh6rb;mlnRJb:fLiPzd;" data-idom-class="CgzRE" jsname="hRZeKc" aria-label="Download attachment image.png" data-tooltip-enabled="true" data-tooltip-id="tt-c9" data-tooltip-classes="AZPksf" id="" jslog="91252; u014N:cOuCgd,Kr2w4b,xr6bB; 4:WyIjbXNnLWY6MTc5ODcwMDg4NTAxODE5ODQ0NSJd; 43:WyJpbWFnZS9wbmciXQ.." disabled=""><span class="OiePBf-zPjgPe VYBDae-JX-UHGRz"></span><span class="bHC-Q" data-unbounded="false" jscontroller="LBaJxb" jsname="m9ZlFb" soy-skip="" ssk="6:RWVI5c"></span><span class="VYBDae-JX-ank-Rtc0Jf" jsname="S5tZuc" aria-hidden="true"><span class="bzc-ank" aria-hidden="true"><svg height="20" viewBox="0 -960 960 960" width="20" focusable="false" class=" aoH"><path d="M480-336 288-528l51-51 105 105v-342h72v342l105-105 51 51-192 192ZM263.72-192Q234-192 213-213.15T192-264v-72h72v72h432v-72h72v72q0 29.7-21.16 50.85Q725.68-192 695.96-192H263.72Z"></path></svg></span></span><div class="VYBDae-JX-ano"></div></button><div class="ne2Ple-oshW8e-J9" id="tt-c9" role="tooltip" aria-hidden="true">Scanning for viruses...</div></span><span data-is-tooltip-wrapper="true" class="a5q" jsaction="JIbuQc:.CLIENT" style="display: none;"><button class="VYBDae-JX-I VYBDae-JX-I-ql-ay5-ays CgzRE" jscontroller="PIVayb" jsaction="click:h5M12e; clickmod:h5M12e;pointerdown:FEiYhc;pointerup:mF5Elf;pointerenter:EX0mI;pointerleave:vpvbp;pointercancel:xyn4sd;contextmenu:xexox;focus:h06R8; blur:zjh6rb;mlnRJb:fLiPzd;" data-idom-class="CgzRE" jsname="XVusie" aria-label="Add attachment to Drive image.png" data-tooltip-enabled="true" data-tooltip-id="tt-c10" data-tooltip-classes="AZPksf" id="" jslog="54185; u014N:xr6bB; 1:WyIjdGhyZWFkLWY6MTc5ODcwMDg4NTAxODE5ODQ0NSJd; 4:WyIjbXNnLWY6MTc5ODcwMDg4NTAxODE5ODQ0NSJd; 43:WyJpbWFnZS9wbmciLDUxMTg3XQ.."><span class="OiePBf-zPjgPe VYBDae-JX-UHGRz"></span><span class="bHC-Q" data-unbounded="false" jscontroller="LBaJxb" jsname="m9ZlFb" soy-skip="" ssk="6:RWVI5c"></span><span class="VYBDae-JX-ank-Rtc0Jf" jsname="S5tZuc" aria-hidden="true"><span class="bzc-ank" aria-hidden="true"><svg height="20" viewBox="0 -960 960 960" width="20" focusable="false" class=" aoH"><path d="M232-120q-17 0-31.5-8.5t-22.29-22.09L80.79-320.41Q73-334 73-351t8-31l248-427q8-14 22.5-22.5t31.06-8.5h194.88q16.56 0 31.06 8.5t22.42 22.37L811-500q-21-5-42-4.5t-42 4.5L571-768H389L146-351l92 159h337q11 21.17 25.5 39.59Q615-134 634-120H232Zm68-171-27-48 172.95-302H514l110 192q-14.32 13-26.53 28.5T576-388l-96-168-111 194h196q-6 17-9.5 34.7-3.5 17.71-3.5 36.3H300Zm432 147v-108H624v-72h108v-108h72v108h108v72H804v108h-72Z"></path></svg></span></span><div class="VYBDae-JX-ano"></div></button><div class="ne2Ple-oshW8e-J9" id="tt-c10" role="tooltip" aria-hidden="true">Add to Drive</div></span><span data-is-tooltip-wrapper="true" class="a5q" jsaction="JIbuQc:.CLIENT" style="display: none;"><button class="VYBDae-JX-I VYBDae-JX-I-ql-ay5-ays CgzRE" jscontroller="PIVayb" jsaction="click:h5M12e; clickmod:h5M12e;pointerdown:FEiYhc;pointerup:mF5Elf;pointerenter:EX0mI;pointerleave:vpvbp;pointercancel:xyn4sd;contextmenu:xexox;focus:h06R8; blur:zjh6rb;mlnRJb:fLiPzd;" data-idom-class="CgzRE" jsname="wtaDCf" aria-label="Save to Photos" data-tooltip-enabled="true" data-tooltip-id="tt-c11" data-tooltip-classes="AZPksf" id="" jslog="54186; u014N:xr6bB; 1:WyIjdGhyZWFkLWY6MTc5ODcwMDg4NTAxODE5ODQ0NSJd; 4:WyIjbXNnLWY6MTc5ODcwMDg4NTAxODE5ODQ0NSJd; 43:WyJpbWFnZS9wbmciLDUxMTg3XQ.."><span class="OiePBf-zPjgPe VYBDae-JX-UHGRz"></span><span class="bHC-Q" data-unbounded="false" jscontroller="LBaJxb" jsname="m9ZlFb" soy-skip="" ssk="6:RWVI5c"></span><span class="VYBDae-JX-ank-Rtc0Jf" jsname="S5tZuc" aria-hidden="true"><span class="bzc-ank" aria-hidden="true"><svg height="20" viewBox="0 -960 960 960" width="20" focusable="false" class=" aoH"><path d="M516-384h72v-132h132v-72H588v-132h-72v132H384v72h132v132ZM312-240q-29.7 0-50.85-21.15Q240-282.3 240-312v-480q0-29.7 21.15-50.85Q282.3-864 312-864h480q29.7 0 50.85 21.15Q864-821.7 864-792v480q0 29.7-21.15 50.85Q821.7-240 792-240H312Zm0-72h480v-480H312v480ZM168-96q-29.7 0-50.85-21.15Q96-138.3 96-168v-552h72v552h552v72H168Zm144-696v480-480Z"></path></svg></span></span><div class="VYBDae-JX-ano"></div></button><div class="ne2Ple-oshW8e-J9" id="tt-c11" role="tooltip" aria-hidden="true">Save to Photos</div></span></div></span></p>
</td>
<td style="text-align:left;border-left:1pt solid rgb(255,121,59);padding:0.75pt;width:2.55pt;height:105.75pt">
</td>
<td style="text-align:left;padding:0.75pt;width:1.8pt;height:105.75pt"></td>
<td style="text-align:left;padding:0.75pt;width:203.2pt;height:105.75pt">
<table style="text-align:left;width:180pt;box-sizing:border-box;border-collapse:collapse;border-spacing:0px">
<tbody>
<tr>
<td style="text-align:left;padding:0.75pt;width:16.5pt;height:18.75pt">
<table style="text-align:left;box-sizing:border-box;border-collapse:collapse;border-spacing:0px">
<tbody>
<tr>
<td style="text-align:left;padding:0.75pt;vertical-align:bottom;width:11.25pt;height:14.1pt">
<p style="text-align:left;line-height:12.6pt;margin-top:0px;margin-bottom:0px">
<span style="font-family:&quot;Times New Roman&quot;,serif;font-size:11.5pt;color:black;background-color:rgb(255,121,59)"><img id="m_8042271865442434460x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_Picture_x0020_4" width="12" height="12" style="width:9pt;height:9pt;min-width:auto;min-height:auto;margin:0px;vertical-align:top" size="280" src="tele_icon.png" data-image-whitelisted="" class="CToWUd" data-bit="iit">
</span></p>
</td>
</tr>
</tbody>
</table>
</td>
<td style="text-align:left;padding:0.75pt;width:159pt;height:18.75pt">
<p style="text-align:left;line-height:12.6pt;margin-top:0px;margin-bottom:0px">
<span style="font-family:&quot;Times New Roman&quot;,serif;font-size:11.5pt;color:black">(689)6899686</span></p>
</td>
</tr>
<tr>
<td style="text-align:left;padding:0.75pt;width:16.5pt;height:18.75pt">
<table style="text-align:left;box-sizing:border-box;border-collapse:collapse;border-spacing:0px">
<tbody>
<tr>
<td style="text-align:left;padding:0.75pt;vertical-align:bottom;width:11.25pt;height:14.1pt">
<p style="text-align:left;line-height:12.6pt;margin-top:0px;margin-bottom:0px">
<span style="font-family:&quot;Times New Roman&quot;,serif;font-size:11.5pt;color:black;background-color:rgb(255,121,59)"><img id="m_8042271865442434460x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_Picture_x0020_3" width="12" height="12" style="width:9pt;height:9pt;min-width:auto;min-height:auto;margin:0px;vertical-align:top" size="260" src="mail_icon.png" data-image-whitelisted="" class="CToWUd" data-bit="iit">
</span></p>
</td>
</tr>
</tbody>
</table>
</td>
<td style="text-align:left;padding:0.75pt;width:159pt;height:18.75pt">
<p style="text-align:left;line-height:12.6pt;margin-top:0px;margin-bottom:0px">
<span style="font-family:&quot;Segoe UI&quot;,sans-serif;font-size:11.5pt;color:rgb(5,99,193)"><u><a href="mailto:info@acsunshine.com" id="m_8042271865442434460OWA70909bba-7f3e-9d12-9b70-ee839813c567" style="color:rgb(5,99,193);margin:0px" target="_blank">info@acsunshine.com</a></u></span></p>
</td>
</tr>
<tr>
<td style="text-align:left;padding:0.75pt;width:16.5pt;height:18.75pt">
<table style="text-align:left;box-sizing:border-box;border-collapse:collapse;border-spacing:0px">
<tbody>
<tr>
<td style="text-align:left;padding:0.75pt;vertical-align:bottom;width:11.25pt;height:14.1pt">
<p style="text-align:left;line-height:12.6pt;margin-top:0px;margin-bottom:0px">
<span style="font-family:&quot;Times New Roman&quot;,serif;font-size:11.5pt;color:black;background-color:rgb(255,121,59)"><img id="m_8042271865442434460x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_Picture_x0020_2" width="12" height="12" style="width:9pt;height:9pt;min-width:auto;min-height:auto;margin:0px;vertical-align:top" size="354" src="link_icon.png" data-image-whitelisted="" class="CToWUd" data-bit="iit">
</span></p>
</td>
</tr>
</tbody>
</table>
</td>
<td style="text-align:left;padding:0.75pt;width:159pt;height:18.75pt">
<p style="text-align:left;line-height:12.6pt;margin-top:0px;margin-bottom:0px">
<span style="font-family:&quot;Times New Roman&quot;,serif;font-size:11.5pt;color:rgb(5,99,193)"><u><a href="https://www./" id="m_8042271865442434460OWA075b0c21-36d7-5bed-9c9c-96407251756e" style="color:rgb(5,99,193);margin:0px" target="_blank" data-saferedirecturl="https://www.google.com/url?q=https://www./&amp;source=gmail&amp;ust=1715782052584000&amp;usg=AOvVaw1Ik7WuRVFvXpu4LW4dNyeC">https://www.</a><a href="http://acsunshine.com" target="_blank" data-saferedirecturl="https://www.google.com/url?q=http://acsunshine.com&amp;source=gmail&amp;ust=1715782052584000&amp;usg=AOvVaw0Op4LaCwknWuLE9wlV5_93">acsunshine.com</a></u></span></p>
</td>
</tr>
<tr>
<td style="text-align:left;padding:0.75pt;width:16.5pt;height:18.75pt">
<table style="text-align:left;box-sizing:border-box;border-collapse:collapse;border-spacing:0px">
<tbody>
<tr>
<td style="text-align:left;padding:0.75pt;vertical-align:bottom;width:11.25pt;height:14.1pt">
<p style="text-align:left;line-height:12.6pt;margin-top:0px;margin-bottom:0px">
<span style="font-family:&quot;Times New Roman&quot;,serif;font-size:11.5pt;color:black;background-color:rgb(255,121,59)"><img id="m_8042271865442434460x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_x_Picture_x0020_1" width="12" height="12" style="width:9pt;height:9pt;min-width:auto;min-height:auto;margin:0px;vertical-align:top" size="632" src="location_icon.png" data-image-whitelisted="" class="CToWUd" data-bit="iit">
</span></p>
</td>
</tr>
</tbody>
</table>
</td>
<td style="text-align:left;padding:0.75pt;width:159pt;height:18.75pt">
<p style="text-align:left;line-height:12.6pt;margin-top:0px;margin-bottom:0px">
<span style="font-family:&quot;Times New Roman&quot;,serif;font-size:11.5pt;color:rgb(68,114,196)">7380 W. Sand Lake, STE 500</span></p>
<p style="text-align:left;line-height:12.6pt;margin-top:0px;margin-bottom:0px">
<span style="font-family:&quot;Times New Roman&quot;,serif;font-size:11.5pt;color:rgb(68,114,196)">Orlando, FL 32819</span></p>
</td>
</tr>
</tbody>
</table>
</td>
</tr>
</tbody>
</table>
</td>
</tr>
</tbody>
</table>
<p style="text-align:left;text-indent:0px;background-color:white;margin:0px">
<span style="font-family:Aptos,sans-serif;font-size:8pt;color:rgb(153,153,153)">This email and any attachments may be confidential, privileged or otherwise exempt from disclosure under applicable law. No confidentiality or privilege is waived or lost
 by any transmission errors. This communication is intended solely for the intended recipient, and if you are not the intended recipient, please notify the sender immediately by return email, delete it from your system and do not copy, distribute, disclose,
 or otherwise act upon any part of this email communication or its attachments. Unauthorized reading, dissemination, distribution, or copying of this communication is prohibited. AC Sunshine Securities LLC does not guarantee the security of any information
 transmitted through email and is not liable for any interception, corruption, or delays. AC Sunshine Securities LLC does not make investment recommendations or decisions, nor offer advice including without limitation investment, legal or tax advice. AC Sunshine
 Securities LLC is&nbsp;a Member of FINRA &amp; SIPC. All Rights Reserved</span></p><div class="yj6qo"></div><div class="adL">
</div></div><div class="adL">

</div></div></div>
        """

# %%
from EmailSender import EmailSender

# %%
test_sender = EmailSender(
    sender_email="info@acsunshine.com",
    password="vjbMDZ8N",
    cc_emails=[
        "eding@acsunshine.com",
        "info@acsunshine.com",
        #"cy@acsunshine.com"    
    ],
    suffix_content=html_content_long
)
test_sender.suffix_addresses
# Out:
# ['ACS_icon.png',
#  'tele_icon.png',
#  'mail_icon.png',
#  'link_icon.png',
#  'location_icon.png']

# %% [markdown]
# # INLIF

# %%
test_sender.set_template_title("[IMPORTANT] $$Account Number$$ INLIF IPO Allocation")
test_sender.set_template_content("templates/inlif/inlif_allocation_notif.html")
# Out:
# templates/hit/hit_allocation_notification.html utf-8
# ('Template Content: ',
# ...

# %%
hit = pd.read_excel("namelist/hit/hit_allocation_notice_email.xlsx")
hit[:2]
# Out:
#      Account Name Country of Account                         Underwriter  \
# 0  Yu Fong(Bryan)                USA  American Trust Investment Services
# 1         Wei Liu                USA  American Trust Investment Services
#
#   Syndicate/Selling Group Account Number  Shares  Amount  \
# 0             AC Sunshine       88SN6006    3860   15440
# 1             AC Sunshine       88SN6027     590    2360
#
#              Email Address
# 0  BRYANFONG0317@GMAIL.COM
# 1     pumpkinwei@yahoo.com

# %%
for item in hit[:].to_dict('records'):
    print(item['Email Address'])
    test_sender.send_with_content_replacement(
        customer_email = item['Email Address'],
        attachment_addresses=[
        ],
        customer_info = item,
        match_dict = {"Account Number":["Account Number"],
                      "Email Address":["email address"],
                      "Account Name":["Account Name"],
                      "Shares":["Shares"],
                      "Amount":["Amount"]
                      }
    )
# Out:
# BRYANFONG0317@GMAIL.COM
# placeholders:  ['Account Number', 'Shares', 'Amount', 'Account Number']
# template title:  [IMPORTANT] 88SN6006 HIT IPO Allocation
# Send to BRYANFONG0317@GMAIL.COM: [IMPORTANT] 88SN6006 HIT IPO Allocation
# Email sent to BRYANFONG0317@GMAIL.COM
# Send to BRYANFONG0317@GMAIL.COM: [IMPORTANT] 88SN6006 HIT IPO Allocation
# pumpkinwei@yahoo.com
# placeholders:  ['Account Number', 'Shares', 'Amount', 'Account Number']
# template title:  [IMPORTANT] 88SN6027 HIT IPO Allocation
# Send to pumpkinwei@yahoo.com: [IMPORTANT] 88SN6027 HIT IPO Allocation
# Email sent to pumpkinwei@yahoo.com
# Send to pumpkinwei@yahoo.com: [IMPORTANT] 88SN6027 HIT IPO Allocation
# DELZHO888@GMAIL.COM
# placeholders:  ['Account Number', 'Shares', 'Amount', 'Account Number']
# template title:  [IMPORTANT] 88SN6028 HIT IPO Allocation
# Send to DELZHO888@GMAIL.COM: [IMPORTANT] 88SN6028 HIT IPO Allocation
# Email sent to DELZHO888@GMAIL.COM
# ...

# %% [markdown]
# # YAAS

# %%
test_sender.set_template_title("[IMPORTANT] $$Account Number$$ YAAS Allocation")
test_sender.set_template_content("templates/yaas/yaas_allocation_notification.html")
# Out:
# templates/yaas/yaas_allocation_notification.html utf-8
# ('Template Content: ',
# ...

# %%
yaas = pd.read_excel("namelist/yaas/yaas_allocation_notification_2.xlsx")
yaas[:2]
# Out:
#    Unnamed: 0  RR           Account Name Country of Account  \
# 0           0  99  NO.8 CAPITAL LIMITED                  US
# 1           1  99   SPDK INVESTMENT LTD                  US
#
#            Underwriter Syndicate/Selling Group Account Number  Shares  Amount  \
# 0  Aegis Capital Corp.             AC Sunshine      AC9900050     500  2250.0
# 1  Aegis Capital Corp.             AC Sunshine      AC9900064     500  2250.0
#
#    % of Shares  %  of Offering When the account was opened   \
# 0     0.000217        0.000217          2024-03-18 15:01:00
# 1     0.000217        0.000217          2024-03-18 15:01:00
#
#   Controlling Person  If the account is fully funded      Email Address
# 0       juguang zhang                            Yes  1434671183@qq.com
# 1        Tianlong Yin                            Yes    yt66963@126.com

# %%
for item in yaas[:].to_dict('records'):
    print(item['Email Address'])
    test_sender.send_with_content_replacement(
        customer_email = item['Email Address'],
        attachment_addresses=[
        ],
        customer_info = item,
        match_dict = {"Account Number":["Account Number"],
                      "Email Address":["Email Address"],
                      "Account Name":["Account Name"],
                      "Shares":["Shares"],
                      "Amount":["Amount"]
                      }
    )
# Out:
# 1434671183@qq.com
# placeholders:  ['Account Number', 'Shares', 'Amount', 'Account Number']
# template title:  [IMPORTANT] AC9900050 YAAS Allocation
# Send to 1434671183@qq.com: [IMPORTANT] AC9900050 YAAS Allocation
# Email sent to 1434671183@qq.com
# Send to 1434671183@qq.com: [IMPORTANT] AC9900050 YAAS Allocation
# yt66963@126.com
# placeholders:  ['Account Number', 'Shares', 'Amount', 'Account Number']
# template title:  [IMPORTANT] AC9900064 YAAS Allocation
# Send to yt66963@126.com: [IMPORTANT] AC9900064 YAAS Allocation
# Email sent to yt66963@126.com
# Send to yt66963@126.com: [IMPORTANT] AC9900064 YAAS Allocation
# qyg8866@163.com
# placeholders:  ['Account Number', 'Shares', 'Amount', 'Account Number']
# template title:  [IMPORTANT] AC9900072 YAAS Allocation
# Send to qyg8866@163.com: [IMPORTANT] AC9900072 YAAS Allocation
# Email sent to qyg8866@163.com
# Send to qyg8866@163.com: [IMPORTANT] AC9900072 YAAS Allocation
# janeqw88@gmail.com
# ...

# %% [markdown]
# ## INLIF

# %%
test_sender.set_template_title("[IMPORTANT] $$Account Number$$ INLIF Deal Announcements UPDATED with your FRGXX Value")
test_sender.set_template_content("templates/inlif/Inlif_deal_anno - Copy.html")
# Out:
# templates/inlif/Inlif_deal_anno - Copy.html utf-8
# ('Template Content: ',
# ...

# %%
inlif_curv = pd.read_csv("namelist/inlif/INLIF_namelist_Curv.csv")
inlif_curv_test = pd.read_csv("namelist/inlif/INLIF_namelist_Curv_test.csv")

inlif_velox = pd.read_csv("namelist/inlif/INLIF_namelist_Velox.csv")
inlif_velox_test = pd.read_csv("namelist/inlif/INLIF_namelist_Velox_test.csv")
inlif_velox = inlif_velox[inlif_velox['Rep'] != 93]

inlif_addup = pd.read_csv("namelist/inlif/INLIF_addup_email_20241031.csv")
inlif_addup
# Out:
#    Unnamed: 0 Account Number           Email Address
# 0           0      AC9900043      zhouds6633@163.com
# 1           1      AC9900086     yonglin0013@163.com
# 2           2      AC9900086     18501936657@163.com
# 3           3      AC9900050       1434671183@qq.com
# 4           4      AC9900064         yt66963@126.com
# 5           5      AC9900072         qyg8866@163.com
# 6           6      AC9900261  hgz15880277702@126.com
# 7           7      AC9900361  uiping1882@hotmail.com
# 8           8      AC9900389      gnoiqw@outlook.com
# 9           9      AC9900357     jqz0904@hotmail.com

# %%
for item in inlif_addup[:].to_dict('records'):
    print(item['Email Address'])
    test_sender.send_with_content_replacement(
        customer_email = item['Email Address'],
        attachment_addresses=[
        ],
        customer_info = item,
        match_dict = {"Account Number":["Account Number"],
                      "Email Address":["email address"],
                      #"Allocated Shares":["Allocation"],
                      #"Cash + FRGXX":["Cash + FRGXX"]
                      }
    )
# Out:
# zhouds6633@163.com
# placeholders:  ['Account Number', 'Account Number']
# template title:  [IMPORTANT] AC9900043 INLIF Deal Announcements UPDATED with your FRGXX Value
# Send to zhouds6633@163.com: [IMPORTANT] AC9900043 INLIF Deal Announcements UPDATED with your FRGXX Value
# Email sent to zhouds6633@163.com
# Send to zhouds6633@163.com: [IMPORTANT] AC9900043 INLIF Deal Announcements UPDATED with your FRGXX Value
# yonglin0013@163.com
# placeholders:  ['Account Number', 'Account Number']
# template title:  [IMPORTANT] AC9900086 INLIF Deal Announcements UPDATED with your FRGXX Value
# Send to yonglin0013@163.com: [IMPORTANT] AC9900086 INLIF Deal Announcements UPDATED with your FRGXX Value
# Email sent to yonglin0013@163.com
# Send to yonglin0013@163.com: [IMPORTANT] AC9900086 INLIF Deal Announcements UPDATED with your FRGXX Value
# 18501936657@163.com
# placeholders:  ['Account Number', 'Account Number']
# ...

# %%
for item in inlif_curv[:].to_dict('records'):
    print(item['Email Address'])
    test_sender.send_with_content_replacement(
        customer_email = item['Email Address'],
        attachment_addresses=[
        ],
        customer_info = item,
        match_dict = {"Account Number":["Account Number"],
                      "Email Address":["email address"],
                      "Allocated Shares":["Allocation"],
                      "Cash + FRGXX":["Cash + FRGXX"]
                      }
    )

# %% [markdown]
# ## CRS Curvature

# %%
test_sender.set_template_title("[IMPORTANT] $$Account Number$$ Your Account Setup Instruction and CRS Documents")
test_sender.set_template_content("templates/CRS_Curv.html")
# Out:
# templates/CRS_Curv.html utf-8
# ('Template Content: ',
# ...

# %%
crs_email = pd.read_csv("namelist/others/Application_20241218.csv")
#crs_email_test = pd.read_csv("namelist/others/CRS_sending_20241001_test.csv")

display(crs_email)
# Out:
#              Email Address Account Number
# 0     melvin.zhang@163.net      AC9900436
# 1  S23084256@gratia.edu.hk      AC9900446

# %%
for item in crs_email[:].to_dict('records'):
    test_sender.send_with_content_replacement(
        customer_email = item['Email Address'],
        attachment_addresses=[
            "attachments/CRS/CRS Commission and Additional Fees AC Sunshine 73123.pdf",
            "attachments/CRS/CRS form 11523 update.pdf",
            "attachments/CRS/Day Trading Risk Disclosure.pdf",
            "attachments/CRS/Wire Instructions Curvature for ACSS Customers_AC99_.pdf",
        ],
        customer_info = item,
        match_dict = {"Account Number":["Account Number"],
                      "Email Address":["email address"]
                      }
    )
# Out:
# placeholders:  ['Email Address', 'Account Number', 'Account Number']
# template title:  [IMPORTANT] AC9900436 Your Account Setup Instruction and CRS Documents
# Send to melvin.zhang@163.net: [IMPORTANT] AC9900436 Your Account Setup Instruction and CRS Documents
# Email sent to melvin.zhang@163.net
# Send to melvin.zhang@163.net: [IMPORTANT] AC9900436 Your Account Setup Instruction and CRS Documents
# placeholders:  ['Email Address', 'Account Number', 'Account Number']
# template title:  [IMPORTANT] AC9900446 Your Account Setup Instruction and CRS Documents
# Send to S23084256@gratia.edu.hk: [IMPORTANT] AC9900446 Your Account Setup Instruction and CRS Documents
# Email sent to S23084256@gratia.edu.hk
# Send to S23084256@gratia.edu.hk: [IMPORTANT] AC9900446 Your Account Setup Instruction and CRS Documents
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# ...

# %% [markdown]
# # CRS Velox

# %%
test_sender.set_template_title("[IMPORTANT] $$Account Number$$ Your Account Setup Instruction and CRS Documents")
test_sender.set_template_content("templates/CRS_Velox.html")
# Out:
# templates/CRS_Velox.html utf-8
# ('Template Content: ',
# ...

# %%
crs_email = pd.read_csv("namelist/others/CRS_sending_20241004.csv")
#crs_email_test = pd.read_csv("namelist/others/CRS_sending_20241001_test.csv")

display(crs_email)
# Out:
#             Email Address Account Number   2   3
# 0     pesha2299@gmail.com       88SN1231  搞定 NaN
# 1     tomweilun@gmail.com       88SN1232  搞定 NaN
# 2  hailei4940@outlook.com       88SN1234  搞定 NaN

# %%
for item in crs_email[:].to_dict('records'):
    test_sender.send_with_content_replacement(
        customer_email = item['Email Address'],
        attachment_addresses=[
            "attachments/CRS/CRS Commission and Additional Fees AC Sunshine 73123.pdf",
            "attachments/CRS/CRS form 11523 update.pdf",
            "attachments/CRS/Day Trading Risk Disclosure.pdf"
        ],
        customer_info = item,
        match_dict = {"Account Number":["Account Number"],
                      "Email Address":["email address"]
                      }
    )
# Out:
# placeholders:  ['Account Number', 'Account Number']
# template title:  [IMPORTANT] 88SN1231 Your Account Setup Instruction and CRS Documents
# Email sent to pesha2299@gmail.com
# Send to pesha2299@gmail.com: [IMPORTANT] 88SN1231 Your Account Setup Instruction and CRS Documents
# placeholders:  ['Account Number', 'Account Number']
# template title:  [IMPORTANT] 88SN1232 Your Account Setup Instruction and CRS Documents
# Email sent to tomweilun@gmail.com
# Send to tomweilun@gmail.com: [IMPORTANT] 88SN1232 Your Account Setup Instruction and CRS Documents
# placeholders:  ['Account Number', 'Account Number']
# template title:  [IMPORTANT] 88SN1234 Your Account Setup Instruction and CRS Documents
# Email sent to hailei4940@outlook.com
# Send to hailei4940@outlook.com: [IMPORTANT] 88SN1234 Your Account Setup Instruction and CRS Documents

# %% [markdown]
# # DRS

# %%
test_sender.set_template_title("[IMPORTANT] $$Account Number$$ DRS Documents Required")
test_sender.set_template_content("templates/DRS.html")
# Out:
# templates/DRS.html utf-8
# ('Template Content: ',
# ...

# %%
drs_email = pd.read_csv("namelist/others/DRS_sending_20241004.csv")
drs_email_test = pd.read_csv("namelist/others/DRS_sending_20241004_test.csv")

display(drs_email)
display(drs_email_test)
# Out:
#                Email Address Account Number
# 0        13927204972@139.com      AC9900257
# 1            dog5937@163.com      AC9900331
# 2  juanjuanzzz12@outlook.com      AC9900338
#               Email Address Account Number
# 0  erdingliao2000@gmail.com      AC9900257
# 1  erdingliao2000@gmail.com      AC9900331
# 2  erdingliao2000@gmail.com      AC9900338

# %%
for item in drs_email[:].to_dict('records'):
    test_sender.send_with_content_replacement(
        customer_email = item['Email Address'],
        attachment_addresses=[
            "attachments/DRS/DRS Transfer Form (fillable) ACS.pdf",
            "attachments/DRS/Due Diligence Checklist For DWAC or DRS Transferring Stocks.docx",
            "attachments/DRS/Example - Book Entry Continental.pdf",
            "attachments/DRS/Example - Payment for purchase Chinese.pdf",
            "attachments/DRS/Sale Order Checklist.docx",
        ],
        customer_info = item,
        match_dict = {"Account Number":["Account Number"],
                      "Email Address":["email address"]
                      }
    )
# Out:
# placeholders:  ['Account Number']
# template title:  [IMPORTANT]  AC9900257 DRS Documents Required
# Email sent to 13927204972@139.com
# Send to 13927204972@139.com: [IMPORTANT]  AC9900257 DRS Documents Required
# placeholders:  ['Account Number']
# template title:  [IMPORTANT]  AC9900331 DRS Documents Required
# Email sent to dog5937@163.com
# Send to dog5937@163.com: [IMPORTANT]  AC9900331 DRS Documents Required
# placeholders:  ['Account Number']
# template title:  [IMPORTANT]  AC9900338 DRS Documents Required
# Email sent to juanjuanzzz12@outlook.com
# Send to juanjuanzzz12@outlook.com: [IMPORTANT]  AC9900338 DRS Documents Required

# %% [markdown]
# # INNO

# %%
test_sender.set_template_title("[IMPORTANT] $$Account Number$$ This 3rd times we suggest you to sale 100 shares INHD to cover debit and  to reservice money to yourself . Reverse split usually result price continues going down. Velox charge $5/quarter for inactive fee. Keep it longer  cost your account value go down")
test_sender.set_template_content("templates/inno/INNO_Debit.html")
# Out:
# templates/inno/INNO_Debit.html utf-8
# ('Template Content: ',
# ...

# %%
inno_email = pd.read_csv("namelist/inno/call_debit.csv")
inno_email_test = pd.read_csv("namelist/inno/call_debit_test.csv")

display(inno_email)
display(inno_email_test)
# Out:
#     Unnamed: 0 Account Number               Name  Cash Balance  Mkt Value  \
# 0            0       88SN9531       PEILONG YUAN        -10.36         55
# 1            1       88SN9457      JIANWEI ZHENG        -10.27         55
# 2            2       88SN9445        TIFFANY KAN        -10.36         55
# 3            3       88SN9443        TAIYAB SYED        -10.45         55
# 4            4       88SN9440      SANDESH KARKI        -10.45         55
# 5            5       88SN9435      KARKI SUSMITA        -10.45         55
# 6            6       88SN9428     CHANG HUA WANG        -10.27         55
# 7            7       88SN9418            CLEO MA        -10.27         55
# 8            8       88SN9412        WEIFANG SHI        -10.36         55
# 9            9       88SN9411         ZHENYU HUA        -10.36         55
# 10          10       88SN9384         JINXIA SUN        -10.27         55
# 11          11       88SN9373  SHRESTHA GYANSHOR        -10.45         55
# ...

# %%
for item in inno_email[:].to_dict('records'):
    test_sender.send_with_content_replacement(
        customer_email = item['Email Address'],
        attachment_addresses=[
            ],
        customer_info = item,
        match_dict = {"Account Number":["Account Number"],
                      "Email Address":["email address"],
                      "Cash Balance":["Cash Balance"],
                      "Mkt Value":["Market Value"],
                      "Total Equity":["Total Equity"]
                      }
    )
# Out:
# placeholders:  ['Cash Balance', 'Market Value', 'Total Equity', 'Account Number']
# template title:  [IMPORTANT] 88SN9531 This 3rd times we suggest you to sale 100 shares INHD to cover debit and  to reservice money to yourself . Reverse split usually result price continues going down. Velox charge $5/quarter for inactive fee. Keep it longer  cost your account value go down
# Email sent to PEILONGY@HOTMAIL.COM
# Send to PEILONGY@HOTMAIL.COM                              : [IMPORTANT] 88SN9531 This 3rd times we suggest you to sale 100 shares INHD to cover debit and  to reservice money to yourself . Reverse split usually result price continues going down. Velox charge $5/quarter for inactive fee. Keep it longer  cost your account value go down
# placeholders:  ['Cash Balance', 'Market Value', 'Total Equity', 'Account Number']
# ...

# %%
sphl_temp = pd.read_excel("namelist/temp/SPHL.xlsx")
sphl_temp[["Requested share allotment", "Cash + FRGXX", "Equity in account prior to IPO indication"]] = sphl_temp[["Requested share allotment", 
            "Cash + FRGXX", 
            "Equity in account prior to IPO indication"]].fillna(0)

frgxx_temp = pd.read_excel("namelist/temp/temp_frgxx_position.xlsx")
total_temp = pd.read_excel("namelist/temp/temp_total_position.xlsx")

# %%
display(sphl_temp[:3])
display(frgxx_temp[:3])
display(total_temp[:3])
# Out:
#    Rep Account Number                                     Account title   \
# 0   99       88SN9999                                         Xinyue Luo
# 1   99       88SN9998  EQUITY TRUST COMPANY, TRUSTEE, FBO YING CUI, R...
# 2   91       88SN9997                       LOCUST HOLDINGS LLC BUSINESS
#
#   Type of account (cash/margin/dvp) Client type (institutional/retail)  \
# 0                              CASH                             retail
# 1                              CASH                             retail
# 2                            MARGIN                             retail
#
#   Date account was opened  Requested share allotment  Cash + FRGXX  \
# 0              2024-06-11                        0.0           0.0
# 1              2024-06-18                        0.0           0.0
# 2              2023-11-08                        0.0           0.0
#
#    Equity in account prior to IPO indication  \
# 0                                        0.0
# ...

# %%
target_list = ["FRGXX MV", "TD Cash Balance", "TD Total Equity", "Indicated allocated share amount"]

merged = sphl_temp.merge(frgxx_temp, on="Account Number", how="left").merge(total_temp, on="Account Number", how="left")
merged[target_list] = merged[target_list].fillna(0)

# add up
merged["Cash + FRGXX"] = merged["FRGXX MV"] + merged["TD Cash Balance"]
merged['Equity in account prior to IPO indication'] = merged["TD Total Equity"]

# filter
merged = merged[merged['Cash + FRGXX'] >= 400.00]
merged['Indicated allocated share amount'] = ((merged['Cash + FRGXX']//40) *10).apply(lambda x: (x//100)*100 if x>500 else x).astype(int)

# %%
merged[:5]
# Out:
#    Rep Account Number                                     Account title   \
# 1   99       88SN9998  EQUITY TRUST COMPANY, TRUSTEE, FBO YING CUI, R...
# 2   91       88SN9997                       LOCUST HOLDINGS LLC BUSINESS
# 4   99       88SN9992                                   David Ada-Winter
# 5   99       88SN9988                    QUN CUI AND JIN BO JIANG- JTROS
# 7    1       88SN9971                                          BIN XIONG
#
#   Type of account (cash/margin/dvp) Client type (institutional/retail)  \
# 1                              CASH                             retail
# 2                            MARGIN                             retail
# 4                              CASH                             retail
# 5                              CASH                             retail
# 7                              CASH                             retail
#
#   Date account was opened  Requested share allotment  Cash + FRGXX  \
# ...

# %%
merged.to_csv("namelist/temp/SPHL IPO Allocation Velox 20240912.csv")

# %%
curvature_temp = pd.read_csv("namelist/temp/Curvature_temp.csv")

curvature_temp = curvature_temp[curvature_temp['TD Cash Balance'] >=400]
curvature_temp["Indicated allocated share amount"] = (curvature_temp[
                                                        "TD Cash Balance"
                                                    ]//40 * 10).apply(lambda x: (x//100)*100 if x>500 else x).astype(int)

# %%
curvature_temp.to_csv("namelist/temp/SPHL IPO Allocation Curvature 20240912.csv")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
